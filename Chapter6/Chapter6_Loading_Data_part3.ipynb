# %%
""" Binary Data Format """
# Out:
# ' Binary Data Format '

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Ecrire les données au format pickle (serializé)
frame = pd.read_csv('examples/ex1.csv')

# %%
frame
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
frame.to_pickle('examples/frame_pickle')

# %%
# Lire un fichier serializé ( pickled)
pd.read_pickle('examples/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
""" HDF5 Format """
# Out:
# ' HDF5 Format '

# %%
frame = pd.DataFrame({'a':np.random.randn(100)})

# %%
frame
# Out:
#            a
# 0   0.489887
# 1  -2.243058
# 2   0.982459
# 3  -0.532186
# 4   1.010864
# 5  -1.791904
# 6   0.164473
# 7  -1.550757
# 8  -1.203525
# 9  -0.182444
# 10  0.981240
# 11  0.657390
# 12 -0.532648
# 13  1.558367
# 14  1.876034
# 15  0.225877
# 16 -0.315451
# 17 -0.951198
# 18 -2.175326
# 19 -0.538382
# 20  0.276102
# 21  0.966474
# 22 -1.427198
# 23  0.308514
# 24  0.174237
# 25 -2.426193
# 26 -0.552518
# 27 -1.540896
# 28 -1.737048
# 29  0.793591
# ..       ...
# 70  0.277764
# 71  0.445742
# 72 -1.063421
# 73  0.163228
# 74  0.671181
# 75  1.070314
# 76 -0.264619
# 77  1.256694
# 78 -1.207437
# 79 -0.275318
# 80 -1.072444
# 81 -2.076900
# 82  0.808586
# 83  0.815900
# 84 -0.722076
# 85 -2.061946
# 86  2.211357
# 87  0.906025
# 88  0.937976
# 89  1.053069
# 90 -0.564698
# 91  0.893154
# 92 -0.852853
# 93  0.596013
# 94 -0.383969
# 95 -0.873869
# 96  1.505674
# 97 -0.658951
# 98  0.269937
# 99 -0.625534
#
# [100 rows x 1 columns]

# %%
store = pd.HDFStore('mydata.h5')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# __init__.pxd in numpy.import_array (tables\utilsextension.c:18771)()
#
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\users\marwane\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     444         try:
# --> 445             import tables  # noqa
#     446         except ImportError as ex:  # pragma: no cover
#
# c:\users\marwane\appdata\local\programs\python\python36-32\lib\site-packages\tables\__init__.py in <module>()
#      89 # Necessary imports to get versions stored on the cython extension
# ---> 90 from .utilsextension import (
#      91     get_pytables_version, get_hdf5_version, blosc_compressor_list,
#
# tables\utilsextension.pyx in init tables.utilsextension (tables\utilsextension.c:21590)()
#
# __init__.pxd in numpy.import_array (tables\utilsextension.c:18814)()
#
# ImportError: numpy.core.multiarray failed to import
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-234bbdce1858> in <module>()
# ----> 1 store = pd.HDFStore('mydata.h5')
#
# c:\users\marwane\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     446         except ImportError as ex:  # pragma: no cover
#     447             raise ImportError('HDFStore requires PyTables, "{ex}" problem '
# --> 448                               'importing'.format(ex=str(ex)))
#     449
#     450         if complib is not None and complib not in tables.filters.all_complibs:
#
# ImportError: HDFStore requires PyTables, "numpy.core.multiarray failed to import" problem importing

# %%
store

# %%
print("fuck")

# %%
rh
