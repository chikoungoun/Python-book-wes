# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
""" Colors, Markers, Line Styles """
# Out:
# ' Colors, Markers, Line Styles '

# %%
from numpy.random import randn

# %%
#insérer des markers pour les données
plt.plot(randn(30).cumsum(),color='k',linestyle='dashed',marker='x')
# peut être abrégé en : plt.plot(randn(30).cumsum(),'ko--')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.random.rand(30).cumsum()

# %%
plt.plot(data,'k--',label='Default')

# %%
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')

# %%
plt.legend(loc='best')

# %%
""" Ticks, Labels, Legends """
# Out:
# ' Ticks, Labels, Legends '

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
#ticks : les chevrons de données sur les abscisses ou ordonnées
ticks = ax.set_xticks([0,250,500,750,1000])

# %%
#labels pour les ticks afin d'écrire du texte
labels = ax.set_xticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')

# %%
#donner un nom aux abscisses
ax.set_xlabel('Stages')

# %%
#donner un titre au plot
ax.set_title('Jupyter Plot')

# %%
props = {'title':'Mon premier Jupyter Plot',
         'xlabel' : 'Stages'}

# %%
ax.set(**props)#Achtung. Paramétrage concentré
# Out:
# [<matplotlib.text.Text at 0x7bb7910>, <matplotlib.text.Text at 0x7bd6cf0>]

# %%
""" Ajouter des légendes"""
# Out:
# ' Ajouter des légendes'

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum(),'k',label='one')#label

# %%
ax.plot(randn(1000).cumsum(),'k--',label='two')

# %%
ax.plot(randn(1000).cumsum(),'k.',label='three')

# %%
#Afficher les legendes
ax.legend(loc='best')

# %%
""" Annotations et dessins sur un subbplot"""
# Out:
# ' Annotations et dessins sur un subbplot'

# %%
from datetime import datetime

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(1,1,1)

# %%
data = np.random.randn(1000).cumsum()

# %%
ax.plot(data,'k-')

# %%
crisis_data =[(250.,'Peak of internet market'),
              (470.,'Constant of life'),
              (800., 'Chab en Bourse')
             ]

# %%
for date,label in crisis_data:
    ax.annotate(label, xy=(date,5), xytext=(date,10), arrowprops=dict(facecolor='black', headwidth=4, width=2, headlength=4),
               horizontalalignment='left',verticalalignment='top')

# %%
# Refaire avec un example plus simple de matplotlib.org
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)

# %%
line, = ax.plot(t, s, lw=2)

# %%
ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

# %%
ax.set_ylim(-2,2)
# Out:
# (-2, 2)

# %%
#dessiner des formes
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rect = plt.Rectangle((.2,.75),.4,.15,color='k',alpha=.3)

# %%
circ = plt.Circle((.7,.2),.15,color='b',alpha=.3)

# %%
pgon = plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color='g', alpha=0.5)

# %%
ax.add_patch(rect)

# %%
ax.add_patch(circ)

# %%
ax.add_patch(pgon)

# %%
plt.savefig('figpath.png',dpi=400, bbox_inches='tight')
