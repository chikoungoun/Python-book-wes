# %%
import pandas as pd

# %%
import numpy as np

# %%
""" 9.2 Plotting with pandas and seaborn """
# Out:
# ' 9.2 Plotting with pandas and seaborn '

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
"""     Line plots """
# Out:
# '     Line plots '

# %%
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))

# %%
s.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),
                  columns=['A','B','C','D'],
                  index=np.arange(0,100,10)
                 )

# %%
df.plot()#plot d'un Dataframe. Chaque colonne représente une ligne
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
"""     Bar Plots """
# Out:
# '     Bar Plots '

# %%
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))

# %%
data.plot.bar(ax=axes[0],color='k',alpha=0.7)#barres verticales

# %%
data.plot.barh(ax=axes[1],color='k',alpha=0.7)

# %%
# Bar plotting d'un DataFrame
df = pd.DataFrame(np.random.rand(6,4),
                  index=['one','two','three','four','five','six'],
                  columns=pd.Index(['A','B','C','D'],name='Genus')
                 )

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.917422  0.775394  0.054649  0.113957
# two    0.813745  0.968001  0.554661  0.880261
# three  0.707039  0.360636  0.100970  0.031317
# four   0.259532  0.290157  0.972871  0.278204
# five   0.698443  0.961546  0.735709  0.873423
# six    0.698593  0.237093  0.755811  0.196678

# %%
df.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Stacked bar plots
df.plot.barh(stacked=True, alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tips = pd.read_csv('examples/tips.csv')

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# 5         25.29  4.71     No   Sun  Dinner     4
# 6          8.77  2.00     No   Sun  Dinner     2
# 7         26.88  3.12     No   Sun  Dinner     4
# 8         15.04  1.96     No   Sun  Dinner     2
# 9         14.78  3.23     No   Sun  Dinner     2
# 10        10.27  1.71     No   Sun  Dinner     2
# 11        35.26  5.00     No   Sun  Dinner     4
# 12        15.42  1.57     No   Sun  Dinner     2
# 13        18.43  3.00     No   Sun  Dinner     4
# 14        14.83  3.02     No   Sun  Dinner     2
# 15        21.58  3.92     No   Sun  Dinner     2
# 16        10.33  1.67     No   Sun  Dinner     3
# 17        16.29  3.71     No   Sun  Dinner     3
# ...

# %%
party_counts = pd.crosstab(tips['day'],tips['size'])

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:,2:5]

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
#NORMALIZE TO SUM TO 1. ACHTUNG
party_pcts = party_counts.div(party_counts.sum(1),axis=0)

# %%
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Utilisant Seaborn

# %%
import seaborn as sns

# %%
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Bar plot en Seaborn
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')

# %%
#créer nouveau tableau plt
def new_plot():
   plt.figure().add_subplot(111)

# %%
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h')

# %%
"""     Histogram and Density plot"""
# Out:
# '     Histogram and Density plot'

# %%
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#density plot
tips['tip_pct'].plot.density()

# %%
# Histograms and density plot avec Seaborn
comp1 = np.random.normal(0,1,size=200)

# %%
comp2 = np.random.normal(10,2,size=200)

# %%
values = pd.Series(np.concatenate([comp1,comp2]))

# %%
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.distplot(values, bins=100,color='k')

# %%
"""    Scatter or Point plots"""
# Out:
# '    Scatter or Point plots'

# %%
macro = pd.read_csv('examples/macrodata.csv')

# %%
data = macro[['cpi','m1','tbilrate','unemp']]

# %%
trans_data = np.log(data).diff().dropna()

# %%
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
# Scatter plot avec seaborn
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.regplot('m1','unemp',data=trans_data)

# %%
plt.title('Changes in log %s versus log %s' % ('m1','unemp'))

# %%
#Pairplot matrix avec Seaborn
new_plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha':0.2})
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
""" Facet Grids and Categorical Data """
# Out:
# ' Facet Grids and Categorical Data '
